# %%
df = pd.read_csv('tripadvisor_hotel_reviews.csv')
df.head()
# Out:
#                                               Review  Rating
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5

# %%
from wordcloud import WordCloud
from nltk.corpus import  stopwords
cloud = WordCloud(stopwords=stopwords.words('english')).generate(str(df.Review))
cloud

# %%
import matplotlib.pyplot as plt
plt.imshow(cloud)

# %%
cloud = WordCloud(stopwords = stopwords.words('english') , max_words=100 , random_state= 23).generate(str(df.Review))
plt.imshow(cloud)

# %%
cloud = WordCloud(stopwords = stopwords.words('english') , max_words=10 , random_state= 23).generate(str(df.Review))
plt.imshow(cloud)

# %%
cloud = WordCloud(stopwords = stopwords.words('english') , max_words=10 , random_state= 238, height = 400 , width=800).generate(str(df.Review))
plt.imshow(cloud)
